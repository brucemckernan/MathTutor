# %% [markdown]
# # Session 04 — Taylor and Maclaurin Series
#
# **Date:** *(fill in when you work this session)*

# %% [markdown]
# Focus: building series from known ones, using series to evaluate limits (faster than repeated L'Hôpital for $x \to 0$), and approximating function values with error bounds. The standard series to know: $e^x$, $\sin x$, $\cos x$, $\ln(1+x)$, $\frac{1}{1-x}$.

# %% [markdown]
# ## Q1 — Series from a known series
#
# (a) Write the Maclaurin series for $e^x$ (first five terms and the general term).
#
# (b) Hence write the Maclaurin series for $e^{-x^2}$ (first four nonzero terms).
#
# (c) Use your series from (b) to write a series for $\displaystyle\int_0^1 e^{-x^2} \, dx$ and compute it to four decimal places.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Q2 — Limit via Taylor series
#
# Use Taylor series (not L'Hôpital) to evaluate:
#
# $$\lim_{x \to 0} \frac{1 - \cos x}{x^2}$$
#
# Show which terms you keep and why you can discard higher-order terms.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Q3 — Deriving a new series by integration
#
# (a) Write the Maclaurin series for $\dfrac{1}{1+t^2}$ by substituting into the geometric series $\dfrac{1}{1-u} = \sum_{n=0}^\infty u^n$.
#
# (b) Hence derive the Maclaurin series for $\arctan x$ by integrating term by term.
#
# (c) Use your series to write an expression for $\pi$ as an infinite series (substitute a suitable value of $x$).

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Q4 — Taylor series around a non-zero point
#
# Find the Taylor series for $f(x) = \ln x$ centred at $a = 1$, up to and including the $(x-1)^3$ term. Show the pattern for the general term.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ---
# When you are done, paste your answers into the Claude Code chat for feedback.
