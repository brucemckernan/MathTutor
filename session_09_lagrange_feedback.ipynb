# %% [markdown]
# # Session 09 — Lagrange Multipliers: Feedback

# %% [markdown]
# ## Q1 — Warmup: one constraint in $\mathbb{R}^2$

# %% [markdown]
# ### Result: Correct ✓ — two notation slips to address
#
# **Setup and algebra**
# You correctly identified $f(x,y) = x^2 + y^2$ (distance-squared from origin) and constraint $g(x,y) = x + 2y = 5$. The system of equations from $\nabla f = \lambda \nabla g$ was set up and solved correctly:
#
# $$2x = \lambda, \quad 2y = 2\lambda, \quad x + 2y = 5$$
#
# Eliminating $x$ and $\lambda$ gives $\lambda = 2$, $x = 1$, $y = 2$. The closest point is $(1, 2)$, with $f(1,2) = 5$. All correct.
#
# ---
#
# ### Notation slip 1 — $\hat{k}$ vs $\hat{j}$
#
# You wrote:
# $$\nabla f = 2x\,\hat{i} + 2y\,\hat{k}, \qquad \nabla g = 1\,\hat{i} + 2\,\hat{k}$$
#
# In $\mathbb{R}^2$ the two basis vectors are $\hat{i}$ (x-direction) and $\hat{j}$ (y-direction). $\hat{k}$ is the z-direction; using it here is a slip. This didn't affect the calculation since you immediately component-matched correctly, but it's worth being precise:
#
# $$\nabla f = 2x\,\hat{i} + 2y\,\hat{j}, \qquad \nabla g = \hat{i} + 2\hat{j}$$
#
# ---
#
# ### Notation slip 2 — $\nabla f = \lambda\, g$ vs $\nabla f = \lambda\, \nabla g$
#
# You wrote:
# $$\nabla f(x,y) = \lambda\, g(x,y)$$
#
# This conflates the scalar function $g$ with its gradient $\nabla g$. On the left is a vector; on the right $\lambda g(x,y)$ is a scalar — the equation is dimensionally inconsistent. The correct Lagrange condition is:
#
# $$\nabla f = \lambda\, \nabla g$$
#
# i.e., the **gradients** are parallel at a constrained extremum, not the function and the gradient. The line immediately after your condition — component form — is correct, so you clearly knew what you were doing; the slip was in writing the condition itself.
#
# ---
#
# ### Geometric verification
#
# Excellent. Your argument is clean and correct:
#
# 1. The level curve of $f$ through $(1,2)$ is the circle $x^2 + y^2 = 5$.
# 2. The radius vector from the origin to $(1,2)$ is $\mathbf{r} = \langle 1, 2 \rangle$, which is the outward normal to the circle at that point.
# 3. The tangent line to the circle at $(1,2)$ is perpendicular to $\mathbf{r}$, giving $1(x-1) + 2(y-2) = 0 \Rightarrow x + 2y = 5$.
# 4. This is exactly the constraint line — so the circle and the line are tangent at $(1,2)$, confirming it is the extremum.
#
# This is precisely the geometric content of Lagrange multipliers: $\nabla f \parallel \nabla g$ means the level curve of $f$ and the constraint curve share the same normal (equivalently, are tangent) at the solution.

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(5, 5))

# Constraint line x + 2y = 5
x = np.linspace(-1, 4, 300)
ax.plot(x, (5 - x) / 2, 'b-', label=r'$x + 2y = 5$')

# Level curve of f through (1, 2): x^2 + y^2 = 5
theta = np.linspace(0, 2 * np.pi, 300)
ax.plot(np.sqrt(5) * np.cos(theta), np.sqrt(5) * np.sin(theta),
        'r-', label=r'$x^2+y^2=5$')

# Solution point and radius vector
ax.plot(1, 2, 'ko', markersize=7, zorder=5)
ax.annotate(r'$(1,2)$', (1, 2), textcoords='offset points', xytext=(8, 4))
ax.annotate('', xy=(1, 2), xytext=(0, 0),
            arrowprops=dict(arrowstyle='->', color='green', lw=1.5))
ax.plot(0, 0, 'k+', markersize=8)

ax.set_xlim(-2.5, 4)
ax.set_ylim(-2.5, 4)
ax.set_aspect('equal')
ax.axhline(0, color='k', lw=0.5)
ax.axvline(0, color='k', lw=0.5)
ax.legend()
ax.set_title('Level curve tangent to constraint at solution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q2 — Optimisation on a sphere

# %% [markdown]
# ### Result: Correct answers — one important conceptual error in the method
#
# **Notation improvement:** You correctly wrote $\nabla f = \lambda \nabla g$ this time. Good — this was the slip in Q1.
#
# ---
#
# ### Setup and $\lambda$ — correct
#
# Gradients are right:
#
# $$\nabla f = \langle 1, 2, 3 \rangle, \qquad \nabla g = \langle 2x, 2y, 2z \rangle$$
#
# The Lagrange conditions give:
#
# $$x = \frac{1}{2\lambda}, \quad y = \frac{1}{\lambda}, \quad z = \frac{3}{2\lambda}$$
#
# Substituting into the constraint:
#
# $$\frac{1}{4\lambda^2} + \frac{1}{\lambda^2} + \frac{9}{4\lambda^2} = \frac{14}{4\lambda^2} = 1 \implies \lambda^2 = \frac{7}{2}$$
#
# All correct.
#
# ---
#
# ### Conceptual error — x, y, z are not independently $\pm$
#
# You described "eight points of intersection" and evaluated $f$ at all eight sign combinations. **This is not how Lagrange multipliers work**, and it's the main thing to take from this question.
#
# The variables $x$, $y$, $z$ are not free to take signs independently. They are determined by $\lambda$ through:
#
# $$x = \frac{1}{2\lambda}, \quad y = \frac{1}{\lambda}, \quad z = \frac{3}{2\lambda}$$
#
# All three share the same $\lambda$. So a single sign choice for $\lambda$ fixes the signs of all three simultaneously:
#
# - $\lambda = +\sqrt{7/2}$ gives $x > 0,\ y > 0,\ z > 0$
# - $\lambda = -\sqrt{7/2}$ gives $x < 0,\ y < 0,\ z < 0$
#
# There are exactly **two critical points**, not eight. A mixed-sign combination like $(+x, -y, +z)$ cannot arise from any single value of $\lambda$ — such a point lies on the sphere but does not satisfy $\nabla f = \lambda \nabla g$, so it is not a candidate extremum from the Lagrange system.
#
# You happened to get the right answer because the true maximum and minimum (all-positive and all-negative) were among the eight you tested, and they did come out largest and smallest. But the six intermediate evaluations were extraneous — they're not critical points.
#
# **The correct argument after finding $\lambda = \pm\sqrt{7/2}$:** evaluate $f$ at the two critical points:
#
# $$f\bigl|_{\lambda = +\sqrt{7/2}} = x + 2y + 3z = \frac{1}{2\lambda} + \frac{2}{\lambda} + \frac{9}{2\lambda} = \frac{14}{2\lambda} = \frac{7}{\lambda} = \frac{7}{\sqrt{7/2}} = \sqrt{14}$$
#
# $$f\bigl|_{\lambda = -\sqrt{7/2}} = -\sqrt{14}$$
#
# So $\max = \sqrt{14}$, $\min = -\sqrt{14}$ (noting $2\sqrt{7/2} = \sqrt{2 \cdot 7} = \sqrt{14}$).
#
# ---
#
# ### A cleaner way to see the answer
#
# Notice that $f = x + 2y + 3z = \nabla f \cdot \mathbf{r}$ where $\mathbf{r} = \langle x,y,z\rangle$. By the Cauchy–Schwarz inequality:
#
# $$|f| = |\langle 1,2,3\rangle \cdot \mathbf{r}| \leq \|\langle 1,2,3\rangle\| \cdot \|\mathbf{r}\| = \sqrt{14} \cdot 1$$
#
# Equality holds when $\mathbf{r} \parallel \langle 1,2,3\rangle$, i.e. at $\mathbf{r} = \pm\frac{1}{\sqrt{14}}\langle 1,2,3\rangle$. This is the same answer and shows why the extreme values are always $\pm\|\nabla f\|$ for a linear $f$ on the unit sphere.

# %% [markdown]
# ### Elaboration — The evaluation bar notation $f\big|_{\lambda = a}$
#
# This notation means "the value of the expression on the left, evaluated at the condition on the right." It is a compact substitute for writing out a substitution explicitly.
#
# **Three contexts where you'll see it:**
#
# **1. Definite integrals** (most common)
# $$\int_0^1 2x\,dx = \left[x^2\right]_0^1 = 1^2 - 0^2 = 1$$
# The bar with subscript/superscript means: evaluate the antiderivative at the upper limit, subtract the value at the lower limit.
#
# **2. Evaluating a function at a point**
# $$f\big|_{x=3} \quad \text{means} \quad f(3)$$
# Useful when the expression is long and writing $f(3)$ would lose clarity about what is being substituted.
#
# **3. Specifying which case you are in** (what appeared in Q2 feedback)
# $$f\big|_{\lambda = +\sqrt{7/2}}$$
# means: take the expression for $f$ and substitute $\lambda = +\sqrt{7/2}$ throughout. It is shorthand for "in the case $\lambda = +\sqrt{7/2}$."
#
# **When to use it vs alternatives:**
#
# | Situation | Bar notation | Alternative |
# |---|---|---|
# | Definite integral | $\left[F(x)\right]_a^b$ | Almost always use this — it is standard |
# | Simple substitution | $f\big|_{x=3}$ | Just write $f(3)$ if the variable is obvious |
# | Evaluating at a named case | $f\big|_{\lambda=+\sqrt{7/2}}$ | "When $\lambda = +\sqrt{7/2}$, $f = \ldots$" in words |
#
# In Q2 it was used stylistically — the prose alternative is equally valid. The bar is most essential in the definite integral context; elsewhere it is a matter of taste.

# %% [markdown]
# ### Elaboration — The Cauchy–Schwarz inequality
#
# **Statement:** For any two vectors $\mathbf{u}$ and $\mathbf{v}$ in $\mathbb{R}^n$:
#
# $$|\mathbf{u} \cdot \mathbf{v}| \leq \|\mathbf{u}\|\,\|\mathbf{v}\|$$
#
# with equality if and only if $\mathbf{u}$ and $\mathbf{v}$ are parallel.
#
# ---
#
# **Geometric derivation** (most transparent)
#
# Recall the geometric definition of the dot product: $\mathbf{u} \cdot \mathbf{v} = \|\mathbf{u}\|\,\|\mathbf{v}\|\cos\theta$, where $\theta$ is the angle between them. Therefore:
#
# $$|\mathbf{u} \cdot \mathbf{v}| = \|\mathbf{u}\|\,\|\mathbf{v}\|\,|\cos\theta| \leq \|\mathbf{u}\|\,\|\mathbf{v}\|$$
#
# since $|\cos\theta| \leq 1$ always, with equality when $\theta = 0$ or $\pi$ (i.e. parallel vectors). Done.
#
# ---
#
# **Algebraic derivation** (works without assuming the geometric dot product formula — useful in more abstract settings)
#
# Consider $h(t) = \|\mathbf{u} - t\mathbf{v}\|^2 \geq 0$ for all real $t$. Expanding:
#
# $$h(t) = \|\mathbf{u}\|^2 - 2t(\mathbf{u}\cdot\mathbf{v}) + t^2\|\mathbf{v}\|^2 \geq 0$$
#
# This is a quadratic in $t$ that is never negative, so its discriminant must satisfy $\Delta \leq 0$:
#
# $$4(\mathbf{u}\cdot\mathbf{v})^2 - 4\|\mathbf{u}\|^2\|\mathbf{v}\|^2 \leq 0 \implies (\mathbf{u}\cdot\mathbf{v})^2 \leq \|\mathbf{u}\|^2\|\mathbf{v}\|^2$$
#
# Taking square roots gives Cauchy–Schwarz. Equality holds when $h(t) = 0$ for some $t$, meaning $\mathbf{u} = t\mathbf{v}$ — i.e. they are parallel.
#
# ---
#
# **How it applied in Q2**
#
# Your objective $f = x + 2y + 3z$ is a dot product:
#
# $$f = \underbrace{\langle 1, 2, 3\rangle}_{\mathbf{u}} \cdot \underbrace{\langle x, y, z\rangle}_{\mathbf{v}}$$
#
# The constraint $x^2 + y^2 + z^2 = 1$ says $\|\mathbf{v}\| = 1$. Cauchy–Schwarz immediately gives:
#
# $$|f| \leq \|\langle 1,2,3\rangle\| \cdot 1 = \sqrt{1^2 + 2^2 + 3^2} = \sqrt{14}$$
#
# This tells us the **maximum value** of $f$ is $\sqrt{14}$. But where is that maximum achieved? That is a separate question answered by the equality condition.
#
# **Finding the location of the maximum — where $\frac{1}{\sqrt{14}}$ comes from**
#
# Cauchy–Schwarz achieves equality when $\mathbf{v}$ is parallel to $\mathbf{u}$, meaning:
#
# $$\langle x, y, z\rangle = c\,\langle 1, 2, 3\rangle \quad \text{for some scalar } c$$
#
# We have one free parameter $c$, but we also have a constraint to satisfy: $\langle x,y,z\rangle$ must lie on the unit sphere, i.e. $\|\langle x,y,z\rangle\| = 1$. Substituting:
#
# $$\|c\,\langle 1,2,3\rangle\| = 1 \implies |c|\,\|\langle 1,2,3\rangle\| = 1 \implies |c|\,\sqrt{14} = 1 \implies |c| = \frac{1}{\sqrt{14}}$$
#
# So $c = +\dfrac{1}{\sqrt{14}}$ or $c = -\dfrac{1}{\sqrt{14}}$, giving the two critical points:
#
# $$\langle x,y,z\rangle = \pm\frac{1}{\sqrt{14}}\langle 1,2,3\rangle$$
#
# In words: the maximum is achieved at the point on the unit sphere that lies directly along $\langle 1,2,3\rangle$ (or directly opposite for the minimum). The factor $\frac{1}{\sqrt{14}}$ is simply what you need to scale $\langle 1,2,3\rangle$ so that it has length 1 — it is the normalization factor, or equivalently $\frac{1}{\|\langle 1,2,3\rangle\|}$.
#
# So the two quantities $\sqrt{14}$ and $\frac{1}{\sqrt{14}}$ refer to different things:
# - $\sqrt{14} = \|\langle 1,2,3\rangle\|$ is the **maximum value of $f$**
# - $\frac{1}{\sqrt{14}}$ is the **scaling factor applied to $\langle 1,2,3\rangle$** to make it a unit vector (the location of the maximum)
#
# **General pattern:** Whenever you maximise a linear function $\mathbf{c} \cdot \mathbf{x}$ subject to $\|\mathbf{x}\| = 1$, the maximum value is $\|\mathbf{c}\|$ and it is achieved at $\mathbf{x} = \frac{\mathbf{c}}{\|\mathbf{c}\|}$ (the unit vector in the direction of $\mathbf{c}$).
#
# ---
#
# **Where you will encounter Cauchy–Schwarz**
#
# | Context | What it says |
# |---|---|
# | Optimising linear $f$ on a sphere | $\max f = \|\nabla f\|$ (Q2 above) |
# | Triangle inequality | $\|\mathbf{u}+\mathbf{v}\| \leq \|\mathbf{u}\|+\|\mathbf{v}\|$ follows from C-S as a lemma |
# | Statistics | Correlation coefficient $r \in [-1,1]$ because $r = \frac{\mathbf{u}\cdot\mathbf{v}}{\|\mathbf{u}\|\|\mathbf{v}\|}$ and C-S bounds this by 1 |
# | Least squares / projections | Bounding approximation error (Session 03 territory) |
#
# The inequality generalises beyond $\mathbb{R}^n$ to any inner product space, including spaces of functions (where the dot product becomes an integral $\int f g$). That is why it appears throughout analysis, probability, and quantum mechanics — but the vector version above is the form to keep in hand for now.

# %% [markdown]
# ## Q3 — Two constraints

# %% [markdown]
# ### Result: Incorrect — one derivative error propagates through the whole solution
#
# The method and structure are right: you correctly identified $f$, $g$, $h$, set up $\nabla f = \lambda_1 \nabla g + \lambda_2 \nabla h$, and knew you needed both constraints to close the system. There are three errors in total — one in a derivative, one conceptual, one algebraic — detailed below.
#
# ---
#
# ### Error 1 — $h_y = 1$ should be $h_y = 2$
#
# You wrote $h(x,y,z) = x + 2y$, then listed $h_y = 1$. But $\frac{\partial}{\partial y}(x + 2y) = 2$. So:
#
# $$\nabla h = \langle 1,\, 2,\, 0 \rangle \quad \text{(not } \langle 1,1,0\rangle\text{)}$$
#
# **How it propagates.** The $\hat{j}$ component of $\nabla f = \lambda_1 \nabla g + \lambda_2 \nabla h$ should give:
#
# $$2y = \lambda_1 \cdot 1 + \lambda_2 \cdot 2 = \lambda_1 + 2\lambda_2$$
#
# Your version gives $2y = \lambda_1 + \lambda_2$, which is the same as the $\hat{i}$ equation $2x = \lambda_1 + \lambda_2$. This forces $x = y$, which is not true at the solution.
#
# **Quick check:** your answer $(7/18,\, 7/18,\, 2/9)$ satisfies $x + y + z = 1$ ✓ but gives $x + 2y = 7/18 + 14/18 = 7/6 \neq 0$ ✗. It does not lie on the second plane.
#
# ---
#
# ### Error 2 — Constraint 2 was never actually used
#
# With your (internally consistent) $x = y = (\lambda_1+\lambda_2)/2$ and $z = \lambda_1/2$, you correctly substituted into Constraint 1 ($x+y+z=1$) to get:
#
# $$\frac{3\lambda_1 + 2\lambda_2}{2} = 1 \implies 3\lambda_1 + 2\lambda_2 = 2 \tag{A}$$
#
# You should then have substituted into Constraint 2 ($x + 2y = 0$) independently:
#
# $$\frac{\lambda_1+\lambda_2}{2} + 2 \cdot \frac{\lambda_1+\lambda_2}{2} = 0 \implies \frac{3(\lambda_1+\lambda_2)}{2} = 0 \implies \lambda_1 + \lambda_2 = 0 \tag{B}$$
#
# This gives the second independent equation needed to solve for both unknowns. Instead, you rearranged (A) to express $\lambda_1$ in terms of $\lambda_2$, then substituted that rearrangement back into (A) itself. Substituting one rearrangement of an equation back into itself is always circular — it produces $\lambda_2 = \lambda_2$, i.e. $0 = 0$, which carries no information. Constraint 2 appears in your work but was never plugged in with $x$ and $y$ expressed in terms of $\lambda_1, \lambda_2$.
#
# ---
#
# ### Error 3 — A spurious $/2$ and a sign slip masked the circularity
#
# The circular substitution should have collapsed to a tautology, but two algebra slips together produced a non-trivial (wrong) result:
#
# **Slip 1 — spurious factor of $\frac{1}{2}$.** When substituting $\lambda_1 = \frac{2}{3}(1-\lambda_2)$ into $\lambda_2 = 1 - \frac{3\lambda_1}{2}$, an extra $/2$ appeared on $\lambda_1$:
#
# $$\text{Written: } \lambda_2 = 1 - \frac{3}{2} \cdot \frac{\tfrac{2}{3}(1-\lambda_2)}{2} \qquad \text{Correct: } \lambda_2 = 1 - \frac{3}{2} \cdot \tfrac{2}{3}(1-\lambda_2)$$
#
# The correct version simplifies to $\lambda_2 = 1-(1-\lambda_2) = \lambda_2$ — the expected tautology. The extra $/2$ broke the circularity and produced a spurious equation.
#
# **Slip 2 — sign error in expansion.** You then expanded $-\frac{1}{2}(1-\lambda_2)$ as:
#
# $$-\tfrac{1}{2} - \tfrac{1}{2}\lambda_2 \quad \text{(written)} \qquad \text{vs} \qquad -\tfrac{1}{2} + \tfrac{1}{2}\lambda_2 \quad \text{(correct)}$$
#
# The two slips together gave $\lambda_2 = 1/3$, which has no valid derivation from the actual system.
#
# ---
#
# ### Correct Lagrange solution
#
# With $\nabla h = \langle 1, 2, 0\rangle$ the three component equations are:
#
# $$2x = \lambda_1 + \lambda_2 \implies x = \frac{\lambda_1+\lambda_2}{2}$$
# $$2y = \lambda_1 + 2\lambda_2 \implies y = \frac{\lambda_1+2\lambda_2}{2}$$
# $$2z = \lambda_1 \implies z = \frac{\lambda_1}{2}$$
#
# Substituting into the two constraints:
#
# **Constraint 1** $x+y+z=1$:
# $$\frac{\lambda_1+\lambda_2}{2} + \frac{\lambda_1+2\lambda_2}{2} + \frac{\lambda_1}{2} = 1 \implies 3\lambda_1 + 3\lambda_2 = 2 \tag{A}$$
#
# **Constraint 2** $x+2y=0$:
# $$\frac{\lambda_1+\lambda_2}{2} + 2\cdot\frac{\lambda_1+2\lambda_2}{2} = 0 \implies 3\lambda_1 + 5\lambda_2 = 0 \tag{B}$$
#
# Subtract (A) from (B): $\;2\lambda_2 = -2 \implies \lambda_2 = -1$.
#
# Back into (A): $3\lambda_1 - 3 = 2 \implies \lambda_1 = \dfrac{5}{3}$.
#
# Then:
# $$x = \frac{5/3 - 1}{2} = \frac{1}{3}, \quad y = \frac{5/3 + 2(-1)}{2} = -\frac{1}{6}, \quad z = \frac{5/3}{2} = \frac{5}{6}$$
#
# **Verify:** $\frac{1}{3} - \frac{1}{6} + \frac{5}{6} = \frac{2-1+5}{6} = 1$ ✓ and $\frac{1}{3} + 2(-\frac{1}{6}) = \frac{1}{3} - \frac{1}{3} = 0$ ✓
#
# The closest point is $\left(\dfrac{1}{3},\, -\dfrac{1}{6},\, \dfrac{5}{6}\right)$, at distance-squared $f = \dfrac{1}{9} + \dfrac{1}{36} + \dfrac{25}{36} = \dfrac{5}{6}$.
#
# ---
#
# ### Summary of errors
#
# | # | Error | Type | Impact |
# |---|---|---|---|
# | 1 | $h_y = 1$ instead of $2$ | Derivative slip | Wrong $\nabla h$; forces $x = y$; answer fails second constraint |
# | 2 | Constraint 2 never substituted | Conceptual gap | System is underdetermined; only one equation actually used |
# | 3 | Spurious $/2$ + sign slip in expansion | Algebra errors | Masked the circularity; produced a spurious numerical answer |
#
# The overall structure was correct — two multipliers, correct form of the Lagrange condition, intention to use both constraints. All three errors are fixable with care. With $h_y = 2$ corrected and Constraint 2 properly substituted, the system closes cleanly in two steps as shown above.
#
# ---
#
# ### Alternative approach — and your question about it
#
# Your instinct is correct: **this problem is easier without Lagrange multipliers**, and the question was designed as a two-multiplier exercise rather than because Lagrange is the natural tool here.
#
# **Parametric approach.** Because $x + 2y = 0$ is free of $z$, you can immediately write $x = -2y$. Substituting into $x + y + z = 1$:
#
# $$-2y + y + z = 1 \implies z = 1 + y$$
#
# Set $y = t$ as the free parameter. The line of intersection is:
#
# $$(x,y,z) = (-2t,\; t,\; 1+t)$$
#
# Now minimise $f(t) = x^2+y^2+z^2$:
#
# $$f(t) = 4t^2 + t^2 + (1+t)^2 = 6t^2 + 2t + 1$$
#
# $$f'(t) = 12t + 2 = 0 \implies t = -\tfrac{1}{6}$$
#
# $$x = -2\!\left(-\tfrac{1}{6}\right) = \tfrac{1}{3}, \quad y = -\tfrac{1}{6}, \quad z = 1 - \tfrac{1}{6} = \tfrac{5}{6}$$
#
# Same answer, in fewer steps, with no linear system to solve.
#
# **When does Lagrange with two multipliers actually win?**
#
# | Situation | Lagrange | Parametric |
# |---|---|---|
# | Two planes (this problem) | Works but overkill — bigger system | Cleaner: two substitutions reduce to 1D |
# | One plane + one sphere | Lagrange is natural — the sphere makes substitution messy | Hard: sphere doesn't give a clean parametrization |
# | Nonlinear constraints generally | Systematic regardless of shape | Often intractable |
# | Need the $\lambda$ values themselves | Built-in (sensitivity analysis, Q4) | Not available |
#
# The short answer to your question: this problem was set as a Lagrange exercise to practice the two-multiplier setup. In practice, whenever you can explicitly parametrize the constraint set (which two planes always allow), direct minimisation along that parametrization is faster. Lagrange pays off when the constraints are nonlinear or when the intersection is hard to write down explicitly.

# %% [markdown]
# ## Q4 — Interpreting $\lambda$

# %% [markdown]
# ### Result: (a) correct, (b) wrong method, (c) close but key wording error
#
# ---
#
# ### Part (a) — Correct ✓
#
# $\lambda = 2$ from Q1. No issues.
#
# ---
#
# ### Part (b) — Wrong method, wrong answer
#
# You kept $\lambda = 2$ and substituted into the Q1 formula $y = \lambda$, $x = 6 - 2y$, obtaining the point $(2, 2)$ with $f(2,2) = 8$.
#
# The problem is that $\lambda$ is not a fixed property of the problem — it depends on the constraint value. When the constraint changes from $c = 5$ to $c = 6$, $\lambda$ changes too. Using the old $\lambda = 2$ to find the new point treats it as fixed when it isn't.
#
# You can verify $(2, 2)$ is wrong: the closest point on $x + 2y = 6$ to the origin should lie on the perpendicular from the origin to that line. The perpendicular direction is $\langle 1, 2\rangle$ (the normal to the line), so the closest point is $\left(\frac{6}{5}, \frac{12}{5}\right)$, giving $f^* = \frac{36}{25} + \frac{144}{25} = \frac{36}{5} = 7.2$. The point $(2,2)$ gives $f = 8$, which is larger — it is on the constraint line but is not the closest point.
#
# **The correct use of $\lambda$ for part (b).** The Lagrange multiplier is a *sensitivity*: it tells you how much the optimal value changes per unit increase in the constraint right-hand side. Specifically:
#
# $$\frac{d f^*}{dc}\bigg|_{c=5} = \lambda = 2$$
#
# So when $c$ increases by 1 (from 5 to 6):
#
# $$f^*(6) \approx f^*(5) + \lambda \cdot \Delta c = 5 + 2 \times 1 = 7$$
#
# You do not need to find the new point — you just add $\lambda$ to the old minimum value. The answer to (b) is: **new minimum $\approx 7$**.
#
# (The exact answer is $36/5 = 7.2$; the approximation is slightly off because $f^*$ is quadratic in $c$, so the linear estimate undershoots by a small amount. For an exam, the sensitivity estimate $7$ is the expected answer.)
#
# ---
#
# ### Part (c) — Right idea, key wording error
#
# You wrote: *"lambda is telling us how much the maximum/minimum will change for a unit increase/decrease **in $\lambda$**"*
#
# The italicised phrase is the error. $\lambda$ is not changing with respect to itself — it is measuring sensitivity with respect to the **constraint value** $c$ (the right-hand side of the constraint equation). The correct statement:
#
# > $\lambda$ measures the rate of change of the optimal value of $f$ with respect to the right-hand side of the constraint. If the constraint is $g(x,y) = c$, then $\dfrac{df^*}{dc} = \lambda$.
#
# In plain language: if you tighten or relax the constraint by one unit, the optimal value changes by approximately $\lambda$.
#
# The second sentence of your answer — "the extrema will move to new coordinates $(2,2)$ with a value of $v + \lambda$" — conflates the new coordinates (which you cannot read off from $\lambda$ alone) with the new optimal value (which $\lambda$ does predict, via $f^* + \lambda \cdot \Delta c$). The value prediction is right in spirit; the coordinate claim is not.
#
# ---
#
# ### Summary
#
# | Part | Result | Issue |
# |---|---|---|
# | (a) | ✓ Correct | $\lambda = 2$ |
# | (b) | ✗ Wrong | Used old $\lambda$ to find a new point instead of using $\lambda$ as a sensitivity to predict the new optimal value: $f^*(6) \approx 5 + 2 = 7$ |
# | (c) | Partially correct | Right concept, but "per unit change in $\lambda$" should be "per unit change in the constraint value $c$" |

# %% [markdown]
# ### Elaboration — Interpretations of the Lagrange multiplier $\lambda$
#
# $\lambda$ is one of those quantities that looks different depending on which field you approach it from. All the interpretations below are consistent — they are different lenses on the same mathematical object.
#
# ---
#
# | Interpretation | What $\lambda$ represents | Context | Example from this session |
# |---|---|---|---|
# | **Proportionality constant** | The scalar $\lambda$ such that $\nabla f = \lambda \nabla g$ at the optimum. The two gradient vectors are parallel; $\lambda$ is their ratio of magnitudes. | Pure algebra / any Lagrange problem | Q1: $\nabla f = \langle 2,4\rangle$, $\nabla g = \langle 1,2\rangle$, so $\lambda = 2$ (∇f is twice ∇g) |
# | **Sensitivity / marginal value** | $\lambda = \dfrac{df^*}{dc}$, where $c$ is the right-hand side of the constraint $g = c$. Increasing $c$ by one unit increases the optimal value by approximately $\lambda$. | Calculus / constrained optimisation | Q4(b): constraint shifts from $c=5$ to $c=6$, so $f^* \approx 5 + 2\cdot1 = 7$ |
# | **Shadow price** | The monetary value of relaxing the constraint by one unit. If $f$ is profit and the constraint is a resource budget, $\lambda$ is how much extra profit one more unit of resource buys. | Economics / operations research | A firm maximising profit subject to a labour constraint: $\lambda$ = value of one extra hour of labour |
# | **Geometric tangency ratio** | At the optimum, the level surface of $f$ and the constraint surface are tangent. $|\lambda|$ measures how much the level surfaces of $f$ are "compressed" relative to those of $g$ at the contact point. | Multivariable geometry | Q1: the circle $x^2+y^2=5$ is tangent to the line $x+2y=5$ at $(1,2)$; the normal vectors are $\langle 2,4\rangle$ and $\langle 1,2\rangle$, ratio $= 2 = \lambda$ |
# | **Constraint force** | When $f$ is potential energy and $g=0$ is a geometric constraint on a physical system, $\lambda\,\nabla g$ is the reaction force the constraint exerts on the system — the force that keeps it on the surface. | Classical mechanics / physics | A bead on a wire: $\lambda$ is the magnitude of the normal force the wire exerts on the bead |
# | **Dual variable** | $\lambda$ is the variable in the dual optimisation problem. Strong duality says the optimal dual value equals the optimal primal value; $\lambda$ prices the constraint in the Lagrangian $\mathcal{L} = f - \lambda(g - c)$. | Convex optimisation / linear programming | The dual of a linear program: shadow prices on constraints equal the optimal $\lambda$ values |
#
# ---
#
# **Which interpretation to reach for:**
#
# - In a standard calculus problem, think **sensitivity** — it is the most directly useful and is what (b) and (c) tested.
# - When checking your work geometrically, think **proportionality / tangency**.
# - If the problem has a real-world resource or cost story, think **shadow price**.
# - The constraint force and dual variable interpretations become important in physics and optimisation theory respectively; you will encounter them if you study mechanics or convex optimisation.
#
# All interpretations agree on the sign of $\lambda$: a positive $\lambda$ means $f$ and $g$ increase in the same direction at the optimum; a negative $\lambda$ means they increase in opposite directions.
