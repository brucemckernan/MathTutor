# %% [markdown]
# # Session 08 — Feedback: Trigonometric Substitution and Partial Fractions

# %% [markdown]
# ## Q1 Feedback — $\int \dfrac{dx}{\sqrt{9 - x^2}}$
#
# **Result: ✓ Fully correct.**
#
# ---
#
# ### What you did well
#
# Every step is correct:
#
# - Recognised the $a^2 - x^2$ pattern with $a = 3$.
# - Set $x = 3\sin\theta$, $dx = 3\cos\theta\,d\theta$.
# - Applied $1 - \sin^2\theta = \cos^2\theta$ to collapse $\sqrt{9 - 9\sin^2\theta} = 3\cos\theta$.
# - The $3\cos\theta$ factors cancelled, leaving $\int 1\,d\theta = \theta$.
# - Back-substituted $\theta = \arcsin(x/3)$ to reach
#
# $$\boxed{\arcsin\!\left(\frac{x}{3}\right) + C}$$
#
# ---
#
# ### Two points worth internalising
#
# **1. Why $\sin$, not $\cos$?**
#
# Your triangle intuition (mapping $x$ to the opposite side) is a valid mnemonic, but the algebraic reason is cleaner: you need $a^2 - x^2$ to factor as a perfect square so the square root disappears. Substituting $x = a\sin\theta$ gives
#
# $$a^2 - x^2 = a^2 - a^2\sin^2\theta = a^2(1 - \sin^2\theta) = a^2\cos^2\theta$$
#
# and $\sqrt{a^2\cos^2\theta} = a\cos\theta$ (on the principal branch). You could equally set $x = a\cos\theta$ — the algebra works — but you'd get $-\sin\theta$ terms and the simplification is slightly messier. $\sin$ is the conventional choice.
#
# The three standard patterns and their substitutions:
#
# | Form in integrand | Substitution | Identity used |
# |---|---|---|
# | $\sqrt{a^2 - x^2}$ | $x = a\sin\theta$ | $1 - \sin^2\theta = \cos^2\theta$ |
# | $\sqrt{a^2 + x^2}$ | $x = a\tan\theta$ | $1 + \tan^2\theta = \sec^2\theta$ |
# | $\sqrt{x^2 - a^2}$ | $x = a\sec\theta$ | $\sec^2\theta - 1 = \tan^2\theta$ |
#
# Worth committing to memory — Session 8 Q2 uses the second pattern.
#
# **2. The sign assumption on $\cos\theta$ — in detail**
#
# At the step $\sqrt{9\cos^2\theta} = 3\cos\theta$ you implicitly used the fact that
#
# $$\sqrt{u^2} = |u|, \quad\text{not always }u.$$
#
# So the algebraically correct statement is $\sqrt{9\cos^2\theta} = 3|\cos\theta|$. You can drop the absolute value only when you know $\cos\theta \geq 0$.
#
# **Why the principal branch makes it valid.**
#
# When we write $x = 3\sin\theta$ and then back-substitute $\theta = \arcsin(x/3)$, we commit to the principal branch of arcsin:
#
# $$\theta \in \left[-\frac{\pi}{2},\, \frac{\pi}{2}\right].$$
#
# Cosine is non-negative on that entire interval, so $\cos\theta \geq 0$ throughout, and $|\cos\theta| = \cos\theta$ with no caveat.
#
# **Stepwise example on the principal branch ($\theta = \pi/6$).**
#
# Take $x = 3/2$. Then $\sin\theta = 1/2 \Rightarrow \theta = \pi/6$ (principal branch).
#
# | Quantity | Value |
# |---|---|
# | $\cos(\pi/6)$ | $\sqrt{3}/2 > 0$ ✓ |
# | $\sqrt{9 - x^2}$ directly | $\sqrt{9 - 9/4} = \sqrt{27/4} = \tfrac{3\sqrt{3}}{2}$ |
# | $3\cos(\pi/6)$ | $3 \cdot \tfrac{\sqrt{3}}{2} = \tfrac{3\sqrt{3}}{2}$ ✓ |
# | Integrand after substitution | $\dfrac{3\cos\theta}{3\cos\theta}\,d\theta = 1\,d\theta$ ✓ |
#
# Everything agrees; no absolute value needed.
#
# **Counter-example on a different branch ($\theta = 5\pi/6$).**
#
# $\sin(5\pi/6) = 1/2$ as well — same $x = 3/2$ — but now $\theta = 5\pi/6$ (second quadrant, outside the principal branch).
#
# | Quantity | Value |
# |---|---|
# | $\cos(5\pi/6)$ | $-\sqrt{3}/2 < 0$ ✗ |
# | $\sqrt{9\cos^2(5\pi/6)}$ | $3\left|-\tfrac{\sqrt{3}}{2}\right| = \tfrac{3\sqrt{3}}{2}$ (always positive) |
# | $3\cos(5\pi/6)$ (no absolute value) | $-\tfrac{3\sqrt{3}}{2}$ ← **negative**, contradicts a square root |
#
# If you wrote $\sqrt{9\cos^2\theta} = 3\cos\theta$ here without checking, you would assign a **negative value to a square root** — which is impossible. The correct denominator is $3|\cos\theta| = +\tfrac{3\sqrt{3}}{2}$.
#
# Now the simplified integrand is
#
# $$\frac{3\cos\theta}{3|\cos\theta|}\,d\theta = \frac{-\tfrac{3\sqrt{3}}{2}}{+\tfrac{3\sqrt{3}}{2}}\,d\theta = -1\,d\theta$$
#
# so integration gives $-\theta + C$, not $+\theta + C$ — a **sign flip in the answer**. (The errors from the wrong sign and the wrong back-substitution happen to cancel for indefinite integrals, but the intermediate steps are wrong and the approach breaks for definite integrals with bounds in the wrong region.)
#
# **The takeaway.** The principal-branch convention $\theta \in [-\pi/2, \pi/2]$ is not just a notational habit — it is what licenses you to write $\sqrt{\cos^2\theta} = \cos\theta$. State it explicitly once at the top of any trig-substitution working and the rest follows cleanly.

# %%
from sympy import *

x = symbols('x')

integrand = 1 / sqrt(9 - x**2)
result = integrate(integrand, x)
print("Antiderivative:", result)

# Confirm it matches arcsin(x/3)
expected = asin(x / 3)
print("Matches arcsin(x/3)?:", simplify(result - expected) == 0)

# %% [markdown]
# ## Q2 Feedback — $\int \dfrac{x^2}{\sqrt{x^2 + 4}}\,dx$
#
# **Result: Correct approach and algebra throughout, with three points to address: one written typo, a factor of 4 lost at the final step, and the back-substitution left incomplete.**
#
# ---
#
# ### What you did well
#
# The strategy is exactly right, and the hardest part — recognising that $\int\sec^3\theta$ requires IBP and produces a cyclic integral — was handled cleanly. The identity $\tan^2\theta = \sec^2\theta - 1$ at the right moment, and the "move the cyclic term to the left" resolution, are both marks of confident technique.
#
# ---
#
# ### Issue 1 — Typo: $\sqrt{4\sec^2\theta} = 4|\sec\theta|$
#
# The step should read
#
# $$\sqrt{4\sec^2\theta} = 2|\sec\theta|$$
#
# not $4|\sec\theta|$. ($\sqrt{4} = 2$, not $4$.) Your subsequent line $4\int\tan^2\theta\sec\theta\,d\theta$ is actually correct — so you implicitly used $2|\sec\theta|$ in the algebra even though you wrote $4|\sec\theta|$. It's a written slip, not a conceptual one, but worth correcting.
#
# ---
#
# ### Issue 2 — The absolute value and the principal branch
#
# You wrote: *"I cancel $|\sec\theta|$ with one power of $\sec^2\theta$ — as a result the expression can take on any value including negative so I drop the absolute value."*
#
# This reasoning is back to front. Dropping the absolute value makes the expression *less* restricted, not more. The correct reason to drop it is:
#
# When $x = 2\tan\theta$ and we back-substitute $\theta = \arctan(x/2)$, we commit to the **principal branch of arctan**, $\theta\in(-\pi/2,\,\pi/2)$. On that interval $\cos\theta > 0$, so $\sec\theta = 1/\cos\theta > 0$, which means $|\sec\theta| = \sec\theta$ from the very start. State the principal branch at the top of your working and write $\sec\theta$ throughout — no separate sign check is ever needed.
#
# Concretely: $\dfrac{\sec^2\theta}{|\sec\theta|} = \dfrac{\sec^2\theta}{\sec\theta} = \sec\theta$ (positive) because $\sec\theta > 0$ on the principal branch.
#
# **Does restricting to the principal branch limit where the antiderivative is valid?**
#
# No — and this is worth understanding clearly. The restriction is on $\theta$ (the intermediate variable), not on $x$ (the variable in the final answer). Once you back-substitute and write the result in terms of $x$, the antiderivative is valid across the full natural domain of the original integrand.
#
# The reason is that each principal branch is chosen so that it covers every $x$ value the integrand can take, with no gaps:
#
# | Substitution | Principal branch of $\theta$ | $x$ values covered | Natural domain of integrand |
# |---|---|---|---|
# | $x = a\sin\theta$ | $\theta \in [-\pi/2,\, \pi/2]$ | $x \in [-a,\, a]$ | $\sqrt{a^2-x^2}$ defined on $(-a,\,a)$ ✓ |
# | $x = a\tan\theta$ | $\theta \in (-\pi/2,\, \pi/2)$ | $x \in (-\infty,\, \infty)$ | $\sqrt{a^2+x^2}$ defined on all $\mathbb{R}$ ✓ |
# | $x = a\sec\theta$ | $\theta \in [0,\pi/2)\cup(\pi/2,\pi]$ | $\lvert x\rvert \geq a$ | $\sqrt{x^2-a^2}$ defined on $\lvert x\rvert \geq a$ ✓ |
#
# The angles outside the principal branch — say $\theta \in (\pi/2, 3\pi/2)$ — do not add any new $x$ values. They only repeat values already covered. For example with $x = 2\tan\theta$:
#
# - $\theta = \pi$ (excluded): $\tan\pi = 0$, so $x = 0$ — already given by $\theta = 0$.
# - $\theta = 3\pi/4$ (excluded): $\tan(3\pi/4) = -1$, so $x = -2$ — already given by $\theta = -\pi/4$.
#
# Trig functions are periodic and not globally one-to-one. The principal branch picks exactly **one representative $\theta$ for each $x$ value** and discards the redundant repeats — which is also what makes the back-substitution well-defined. For Q2, the final antiderivative
#
# $$\frac{x\sqrt{x^2+4}}{2} - 2\ln\!\left|x+\sqrt{x^2+4}\right| + C$$
#
# is valid for all real $x$. The $\theta$-level bookkeeping was scaffolding for the intermediate computation; once you are back in $x$ it has no further role.
#
# ---
#
# ### Issue 3 — Missing factor of 4: step-by-step
#
# The key is to keep track of **what you are actually trying to find**. After the substitution the original integral becomes:
#
# $$\underbrace{\int\frac{x^2}{\sqrt{x^2+4}}\,dx}_{\text{what we want}} = \underbrace{4\int\tan^2\theta\sec\theta\,d\theta}_{\text{call this }I}$$
#
# So $I = 4\int\tan^2\theta\sec\theta\,d\theta$ is what we need to find — it carries the factor of 4.
#
# **Step 1.** You correctly applied $\tan^2\theta = \sec^2\theta - 1$ and split:
#
# $$I = 4\int(\sec^3\theta - \sec\theta)\,d\theta = 4\int\sec^3\theta\,d\theta - 4\ln|\sec\theta+\tan\theta| \quad \cdots [1]$$
#
# **Step 2.** IBP on $\int\sec^3\theta$:
#
# $$\int\sec^3\theta\,d\theta = \sec\theta\tan\theta - \int\tan^2\theta\sec\theta\,d\theta$$
#
# **Step 3.** Substitute step 2 into [1]:
#
# $$I = 4\!\left[\sec\theta\tan\theta - \int\tan^2\theta\sec\theta\,d\theta\right] - 4\ln|\sec\theta+\tan\theta|$$
#
# $$I = 4\sec\theta\tan\theta - 4\int\tan^2\theta\sec\theta\,d\theta - 4\ln|\sec\theta+\tan\theta|$$
#
# **Step 4.** Notice that $I = 4\int\tan^2\theta\sec\theta\,d\theta$, so the term $4\int\tan^2\theta\sec\theta\,d\theta$ on the right is just $I$ again. Add $I$ to both sides:
#
# $$2I = 4\sec\theta\tan\theta - 4\ln|\sec\theta+\tan\theta|$$
#
# **Step 5.** Divide both sides by 2 to isolate $I$:
#
# $$I = 2\sec\theta\tan\theta - 2\ln|\sec\theta+\tan\theta| + C$$
#
# **What went wrong in your working.**
#
# You reached the same equation as Step 4, written as:
#
# $$8\int\tan^2\theta\sec\theta\,d\theta = 4\sec\theta\tan\theta - 4\ln|\sec\theta+\tan\theta|$$
#
# This is correct. But then you divided by 8 to get
#
# $$\int\tan^2\theta\sec\theta\,d\theta = \tfrac{1}{2}\sec\theta\tan\theta - \tfrac{1}{2}\ln|\sec\theta+\tan\theta| + C$$
#
# and presented this as the final answer. The problem: you solved for the *bare* integral $\int\tan^2\theta\sec\theta\,d\theta$ — which is $\frac{1}{4}$ of what you needed. The original integral is $4$ times that, so multiply back:
#
# $$I = 4\times\left[\tfrac{1}{2}\sec\theta\tan\theta - \tfrac{1}{2}\ln|\sec\theta+\tan\theta|\right] = 2\sec\theta\tan\theta - 2\ln|\sec\theta+\tan\theta| + C$$
#
# Equivalently, from $8\int\tan^2\theta\sec\theta\,d\theta = 4\sec\theta\tan\theta - 4\ln|\sec\theta+\tan\theta|$, divide by 2 (not 8) to read off $I = 4\int\tan^2\theta\sec\theta\,d\theta$ directly:
#
# $$\underbrace{4\int\tan^2\theta\sec\theta\,d\theta}_{= I} = 2\sec\theta\tan\theta - 2\ln|\sec\theta+\tan\theta| + C \checkmark$$
#
# The safest habit: at the start, write a labelled equation $I = \ldots$ for the original integral. At the end, make sure it is $I$ you are solving for, not a sub-piece of it.
#
# ---
#
# ### Issue 4 — Back-substitution (not attempted)
#
# With $x = 2\tan\theta$, draw the reference triangle: opposite $= x$, adjacent $= 2$, hypotenuse $= \sqrt{x^2+4}$. Read off:
#
# $$\tan\theta = \frac{x}{2}, \qquad \sec\theta = \frac{\sqrt{x^2+4}}{2}$$
#
# Substituting into $I = 2\sec\theta\tan\theta - 2\ln|\sec\theta+\tan\theta| + C$:
#
# $$= 2\cdot\frac{\sqrt{x^2+4}}{2}\cdot\frac{x}{2} - 2\ln\!\left|\frac{\sqrt{x^2+4}}{2}+\frac{x}{2}\right| + C$$
#
# $$= \frac{x\sqrt{x^2+4}}{2} - 2\ln\!\left|\frac{x+\sqrt{x^2+4}}{2}\right| + C$$
#
# The $\ln(1/2) = -\ln 2$ that comes out of splitting the log argument is a constant and absorbs into $C$, giving the standard final form:
#
# $$\boxed{\frac{x\sqrt{x^2+4}}{2} - 2\ln\!\left|x + \sqrt{x^2+4}\right| + C}$$
#
# ---
#
# ### Summary
#
# | Step | Status |
# |---|---|
# | Pattern recognition ($\sqrt{a^2+x^2}$, use $x=a\tan\theta$) | ✓ |
# | $dx$ and substitution | ✓ |
# | Simplification via $1+\tan^2\theta = \sec^2\theta$ | ✓ (typo: $4|\sec\theta|$ should be $2|\sec\theta|$) |
# | Principal-branch reasoning for $|\sec\theta|$ | Needs correction (see Issue 2) |
# | $\tan^2\theta \to \sec^2\theta - 1$ substitution | ✓ |
# | IBP on $\int\sec^3\theta$ | ✓ |
# | Cyclic resolution | ✓ |
# | Final factor of 4 | ✗ — solved for $\tfrac{1}{4}I$ instead of $I$ at last step |
# | Back-substitution to $x$ | ✗ — not attempted |

# %%
from sympy import *

x = symbols('x')

integrand = x**2 / sqrt(x**2 + 4)
result = integrate(integrand, x)
print("SymPy result:  ", result)

expected = x * sqrt(x**2 + 4) / 2 - 2 * ln(Abs(x + sqrt(x**2 + 4)))
diff = simplify(result - expected)
print("Difference from expected (should be constant):", diff)

# Verify by differentiating
print("d/dx of expected:", simplify(diff(expected, x) - integrand))

# %% [markdown]
# ## Q2(b) Feedback — $\int \sqrt{x^2+1}\,dx$
#
# **Result: ✓ Correct. One minor omission (missing $+C$). Mathpix LaTeX issues noted below.**
#
# ---
#
# ### Mathematics
#
# The strategy and execution are both right:
#
# - Substitution $x = \tan\theta$, $dx = \sec^2\theta\,d\theta$ ✓
# - $\sqrt{\tan^2\theta+1} = \sqrt{\sec^2\theta} = |\sec\theta| = \sec\theta$ (principal branch of arctan) ✓ — and you correctly stated the reason this time.
# - Recognised $\int\sec^3\theta\,d\theta$ and set up IBP with $u = \sec\theta$, $dv = \sec^2\theta\,d\theta$ ✓
# - Applied $\tan^2\theta = \sec^2\theta - 1$ to convert the residual $\int\tan^2\theta\sec\theta$ ✓
# - Correctly identified the cyclic structure and resolved:
#
# $$2\int\sec^3\theta\,d\theta = \sec\theta\tan\theta + \ln|\sec\theta+\tan\theta|$$
#
# $$\int\sec^3\theta\,d\theta = \tfrac{1}{2}\sec\theta\tan\theta + \tfrac{1}{2}\ln|\sec\theta+\tan\theta| \checkmark$$
#
# - Reference triangle: adjacent $= 1$, opposite $= x$, hypotenuse $= \sqrt{x^2+1}$, so $\tan\theta = x$, $\sec\theta = \sqrt{x^2+1}$ ✓
# - Final answer correct:
#
# $$\boxed{\dfrac{x\sqrt{x^2+1}}{2} + \dfrac{1}{2}\ln\!\left|x + \sqrt{x^2+1}\right| + C}$$
#
# **One omission**: the $+C$ is missing from the final line. Always include it — an antiderivative without $+C$ is technically incomplete.
#
# ---
#
# ### Mathpix LaTeX issues
#
# The new workflow is largely working well — the mathematical structure came through intact. Four recurring issues to watch for:
#
# **1. Capitalised trig function names (`SEC`, `TAN`)**
#
# Mathpix is reading your handwritten uppercase letters and generating `\operatorname{SEC}`, `\operatorname{TAN}`. Standard LaTeX uses the lowercase built-ins: `\sec`, `\tan`, `\sin`, `\cos`. These render differently and are not interchangeable in formal work. When you paste Mathpix output, do a find-and-replace:
#
# | Mathpix output | Correct LaTeX |
# |---|---|
# | `\operatorname{SEC}` | `\sec` |
# | `\operatorname{TAN}` | `\tan` |
# | `\operatorname{SIN}` | `\sin` |
#
# Consider writing trig functions in lowercase on the iPad to help Mathpix recognise them correctly at source.
#
# **2. Stray letter in `SEC C^2` and `SEC C^3`**
#
# Two lines contain `\operatorname{SEC} C^2 \theta` and `\operatorname{SEC} C^3 \theta` — Mathpix has misread the superscript and split `SEC²` into `SEC` followed by a stray `C²`. These should be `\sec^2\theta` and `\sec^3\theta`. This is a common OCR failure when the exponent is written close to the function name.
#
# **3. Spurious `/1` denominator**
#
# The back-substitution line reads $\sec\theta = \dfrac{\sqrt{x^2+1}}{1}$. The $/1$ is an OCR artefact — Mathpix saw the baseline of your writing as a fraction bar. The correct expression is simply $\sec\theta = \sqrt{x^2+1}$.
#
# **4. The `\begin{aligned}` + `\begin{gathered}` nesting**
#
# The nesting is necessary in Jupyter — without an alignment environment, `\\` line breaks inside a single `$$` block collapse to one long line. So keeping an environment is correct. The cleanest options are:
#
# - `\begin{gather*}...\end{gather*}` — centres each line, no alignment column needed. Good for step-by-step working where you don't need to align on `=`.
# - `\begin{align*}...\end{align*}` — aligns lines on a `&` marker. Good when you want `=` signs to line up vertically.
#
# Mathpix's `\begin{aligned}` inside `\begin{aligned}` is redundant (two layers where one suffices), but the real fix is simply to replace the outer `\begin{aligned}` / inner `\begin{gathered}` pair with a single `\begin{gather*}` — same visual result, cleaner source.

# %%
from sympy import *

x = symbols('x')

integrand = sqrt(x**2 + 1)
result = integrate(integrand, x)
print("SymPy result:", result)

expected = x * sqrt(x**2 + 1) / 2 + ln(x + sqrt(x**2 + 1)) / 2
print("Difference from expected (should be 0 or constant):", simplify(result - expected))

# %% [markdown]
# ## Q2(c) Feedback — $\int \dfrac{x^3}{\sqrt{x^2+4}}\,dx$
#
# **Result: ✓ Correct strategy and final answer. Two written errors in the working, one identity misstated in the prose. Good LaTeX improvements.**
#
# ---
#
# ### Mathematics
#
# **What you did well.** Recognising that $\tan^3\theta = \tan^2\theta\cdot\tan\theta$ and that $\tan\theta\sec\theta = \frac{d}{d\theta}(\sec\theta)$ is exactly the key insight — it converts the integral into one that yields to a clean $u$-substitution rather than cyclic IBP. The simplification, factoring, and back-substitution are all handled correctly and the final result
#
# $$\boxed{\dfrac{(x^2-8)\sqrt{x^2+4}}{3} + C}$$
#
# is correct. (Missing $+C$ again — make it a habit.)
#
# **Error 1 — written slip in line 3: $\sqrt{4\tan^2\theta+1}$**
#
# Line 2 correctly has $\sqrt{4\tan^2\theta+4}$. Line 3 changes this to $\sqrt{4\tan^2\theta+1}$ — the constant $4$ became $1$. Line 4 then correctly writes $\sqrt{4\sec^2\theta}$, which can only follow from $\sqrt{4(\tan^2\theta+1)}$, not from $\sqrt{4\tan^2\theta+1}$. So the algebra is implicitly correct but line 3 is a written error. It should read:
#
# $$\int \frac{8\tan^3\theta}{\sqrt{4(\tan^2\theta+1)}} \cdot 2\sec^2\theta\,d\theta$$
#
# **Error 2 — typo in back-substitution: $\sec^3 u$**
#
# After integrating you wrote $8\!\left[\dfrac{\sec^3 u}{3} - \sec\theta\right]$. The $u$ in $\sec^3 u$ should be $\theta$ — it should read $\dfrac{\sec^3\theta}{3}$. You had already back-substituted $u \to \sec\theta$ for the $-u$ term (writing $-\sec\theta$ correctly) but left the other term in a hybrid $u$/$\theta$ form. Both terms should be in $\theta$ before you then substitute $\sec\theta = \frac{\sqrt{x^2+4}}{2}$.
#
# **Note on $u$-substitution notation**
#
# You wrote $u = \sec\theta,\; d\theta = \dfrac{du}{\sec\theta\tan\theta}$. This is algebraically valid but the conventional direction is
#
# $$u = \sec\theta \implies du = \sec\theta\tan\theta\,d\theta$$
#
# and then you substitute $\tan\theta\sec\theta\,d\theta \to du$ directly. Expressing $d\theta$ in isolation isn't wrong but it's not what you actually use — you replace the entire $\tan\theta\sec\theta\,d\theta$ factor, not $d\theta$ alone.
#
# **Identity misstated in the prose**
#
# You wrote: *"I have applied the identity $\sec^2\theta = \tan^2\theta - 1$"*. The sign is wrong. The correct identity is
#
# $$\sec^2\theta = \tan^2\theta + 1 \quad \Longleftrightarrow \quad \tan^2\theta = \sec^2\theta - 1$$
#
# The rearrangement you used in the working ($\tan^2\theta = \sec^2\theta - 1$) is correct — it's only the prose description that has the wrong sign.
#
# ---
#
# ### LaTeX and workflow
#
# **Improvements since Q2(b) — all good:**
# - ✓ Lowercase `\sec`, `\tan` throughout — no more `\operatorname{SEC}`.
# - ✓ Stray `C^2` / `C^3` OCR artefact is gone.
# - ✓ No spurious `/1` denominator.
# - ✓ `\begin{gather*}` used instead of the double-nested `aligned`/`gathered`.
#
# **One remaining issue — leading `&` inside `gather*`**
#
# Every line in your `gather*` block starts with `&`. In `gather*`, there are no alignment columns — `&` has no meaning there, and MathJax may render it as a literal ampersand or produce unexpected spacing. The `&` is appropriate for `align*` (where it marks the alignment point), not for `gather*`.
#
# You have two clean options:
#
# | Environment | What to do with `&` | Effect |
# |---|---|---|
# | `\begin{gather*}` | Remove all leading `&` | Each line centred independently |
# | `\begin{align*}` | Keep `&`, move it to just before each `=` sign | All `=` signs vertically aligned |
#
# Since Mathpix generates `&` markers automatically, the path of least resistance is to **switch back to `align*`** and move each `&` from the start of the line to immediately before the `=` or `\int` where you want alignment. Alternatively, a quick find-and-replace to strip the leading `& ` from each line lets you keep `gather*`.

# %%
from sympy import *

x = symbols('x')

integrand = x**3 / sqrt(x**2 + 4)
result = integrate(integrand, x)
print("SymPy result:", result)

expected = (x**2 - 8) * sqrt(x**2 + 4) / 3
print("Difference from expected (should be 0 or constant):", simplify(result - expected))
print("Verify by differentiating expected:", simplify(diff(expected, x) - integrand))

# %% [markdown]
# ## Q3 Feedback — $\int \dfrac{3x + 5}{x^2 + 3x + 2}\,dx$
#
# **Result: ✓ Fully correct.**
#
# ---
#
# ### What you did well
#
# Every step is right and well-motivated:
#
# - Factored the denominator correctly: $(x+2)(x+1)$.
# - Set up the partial fraction form with constants $A$, $B$ in the numerators (correct, since both factors are linear).
# - Cleared the denominator to get $3x+5 = A(x+2) + B(x+1)$.
# - Used the **cover-up method** (substitute the root of each factor) to isolate $A$ and $B$ without solving a simultaneous system — this is exactly the right shortcut for distinct linear factors:
#   - $x = -1$: $\;2 = A$
#   - $x = -2$: $\;-1 = -B \Rightarrow B = 1$
# - Split the integral and integrated each piece:
#
# $$\boxed{2\ln|x+1| + \ln|x+2| + C}$$
#
# - $+C$ is present — no omission this time.
#
# ---
#
# ### One note on the integration step
#
# You mentioned using $u = x+1$ and $u = x+2$ as u-substitutions. That's the right reasoning, but $\int \frac{1}{x+a}\,dx = \ln|x+a| + C$ is immediate enough that you don't need to name the substitution explicitly in your working — just write the result directly. Once partial fractions are in place the integration is bookkeeping, not technique.
#
# ---
#
# ### LaTeX
#
# **Improvement**: `\begin{gather*}` used throughout, lowercase function names, no stray OCR artefacts. The `$$`-wrapping around `gather*` is harmless — `\begin{gather*}` is a display-math environment on its own in Jupyter, so the outer `$$` is redundant but doesn't break anything.
#
# **Recurring issue**: Leading `&` on every line inside `gather*`. As flagged in Q2(c): `gather*` has no alignment columns, so `&` does nothing there. Either:
# - strip the `& ` prefix from each line (keep `gather*`), or
# - switch to `align*` and place `&` immediately before each `=` sign.
#
# Mathpix will continue generating these — treat it as a standard post-processing step when pasting output.

# %%
from sympy import *

x = symbols('x')

integrand = (3*x + 5) / (x**2 + 3*x + 2)
result = integrate(integrand, x)
print("SymPy result:", result)

expected = 2*ln(Abs(x + 1)) + ln(Abs(x + 2))
print("Difference from expected (should be 0 or constant):", simplify(result - expected))
print("Verify by differentiating expected:", simplify(diff(expected, x) - integrand))

# %% [markdown]
# ## Q4 Feedback — $\int \dfrac{x^2 + 1}{(x-1)(x+1)^2}\,dx$
#
# *Awaiting your answer.*
