# %% [markdown]
# # Session 13 — Feedback: Trig Substitution, Logarithmic Integration, and Inverse Functions

# %% [markdown]
# ## Q1 Feedback — $\int \dfrac{dx}{\sqrt{x^2 - 9}}$
#
# *Awaiting your answer.*

# %% [markdown]
# ## Q2 Feedback — $\int \dfrac{x^2}{\sqrt{1 - x^2}}\,dx$
#
# *Awaiting your answer.*

# %% [markdown]
# ## Q3 Feedback — $\int \dfrac{dx}{(x^2 + 1)^2}$
#
# *Awaiting your answer.*

# %% [markdown]
# ## Q4 Feedback — $\int \sqrt{4x - x^2}\,dx$
#
# *Awaiting your answer.*

# %% [markdown]
# ## Q5 Feedback — $\int \dfrac{3x^2 + 2}{x^3 + 2x + 1}\,dx$
#
# *Awaiting your answer.*

# %% [markdown]
# ## Q6 Feedback — $\int \tan x\,dx$
#
# *Awaiting your answer.*

# %% [markdown]
# ## Q7 Feedback — $\int \dfrac{1}{x(\ln x)^2}\,dx$
#
# *Awaiting your answer.*

# %% [markdown]
# ## Q8 Feedback — Inverse of $f(x) = \dfrac{2x+3}{x-1}$
#
# *Awaiting your answer.*

# %% [markdown]
# ## Q9 Feedback — Inverse of $f(x) = e^{x-1} - 2$
#
# *Awaiting your answer.*

# %% [markdown]
# ## Q10 Feedback — $(f^{-1})'(3)$ for $f(x) = x^5 + 2x$
#
# *Awaiting your answer.*

# %% [markdown]
# ## Q11 Feedback — Derive $\dfrac{d}{dx}[\arcsin x]$
#
# *Awaiting your answer.*
